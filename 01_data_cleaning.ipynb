# %%
pip install --upgrade --force-reinstall geopandas
# Out:
# ...
#   Using cached geopandas-0.12.2-py3-none-any.whl (1.1 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 5.5 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached shapely-2.0.1-cp38-cp38-macosx_10_9_x86_64.whl (1.4 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 5.7 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 6.1 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached munch-2.5.0-py2.py3-none-any.whl (10 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 4.0 MB/s eta 0:00:0000:01
# ...
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# ...
#   Using cached click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# ...
#   Using cached cligj-0.7.2-py3-none-any.whl (7.1 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 5.1 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import geopandas as gpd

# %%
import geopandas as gpd
import pandas as pd
import datetime
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import geopandas as gpd
#       2 import pandas as pd
#       3 import datetime
#
# File /opt/homebrew/anaconda3/envs/TFM_3/lib/python3.8/site-packages/geopandas/__init__.py:1
# ----> 1 from geopandas.geoseries import GeoSeries  # noqa
#       2 from geopandas.geodataframe import GeoDataFrame  # noqa
#       3 from geopandas.array import _points_from_xy as points_from_xy  # noqa
#
# File /opt/homebrew/anaconda3/envs/TFM_3/lib/python3.8/site-packages/geopandas/geoseries.py:12
#       9 from pandas.core.internals import SingleBlockManager
#      11 import pyproj
# ---> 12 from shapely.geometry.base import BaseGeometry
#      13 from shapely.ops import transform
#      15 from geopandas.base import GeoPandasBase, _delegate_property
#
# ...

# %%
incendios_93_19 = gpd.read_file("data/incendios_files/ince_incendios0.shx")

# %%
incendios_93_19
# Out:
#        et_id    numparte  anyo  c_a              ccaa_nom  prov
# 0          0  2009120076  2009    9  Comunitat Valenciana    12  \
# 1          1  1997030075  1997    9  Comunitat Valenciana     3
# 2          2  2012460249  2012    9  Comunitat Valenciana    46
# 3          3  2001120101  2001    9  Comunitat Valenciana    12
# 4          4  1996126044  1996    9  Comunitat Valenciana    12
# ...      ...         ...   ...  ...                   ...   ...
# 11792      0  2019460041  2019    9  Comunitat Valenciana    46
# 11793      0  2019460041  2019    9  Comunitat Valenciana    46
# 11794      0  2019120004  2019    9  Comunitat Valenciana    12
# 11795      0  2019460005  2019    9  Comunitat Valenciana    46
# 11796      0  2019120012  2019    9  Comunitat Valenciana    12
#
#                  prov_nom  comarca               com_nom  com_codicv  ...
# 0      Castellón/Castelló     1207      El Alto Palancia           8  ...  \
# ...

# %%
incendios_93_19['f_detec']
# Out:
# 0        23/07/2009
# 1        28/08/1997
# 2        23/09/2012
# 3        29/08/2001
# 4        24/07/1996
#             ...
# 11792    21/03/2019
# 11793    21/03/2019
# 11794    03/02/2019
# 11795    27/01/2019
# 11796    18/05/2019
# Name: f_detec, Length: 10271, dtype: object

# %%
# Comprobamos duplicados
incendios_93_19.geometry.duplicated().sum()
# Out:
# 1526

# %%
incendios_93_19.drop_duplicates(subset=['geometry'], inplace=True)

# %%
# Comprovació nulos en la fecha
incendios_93_19[incendios_93_19['f_detec'].isna()]
# Out:
# Empty GeoDataFrame
# Columns: [et_id, numparte, anyo, c_a, ccaa_nom, prov, prov_nom, comarca, com_nom, com_codicv, c_muni, codmun, nom_mun, e_m, paraje, hoja, cuad, huso, x, y, f_detec, f_det_amd, h_detec, f_pm_ter, h_pm_ter, fpm_aeext, hpm_aeext, fpbrighel, hpbrighel, fcontrol, hcontrol, fextinc, hextinc, detecpor, detecp_txt, vigfij, inijunta, inijun_txt, t_causa, t_caus_txt, g_causa, g_caus_txt, causas, motivac, motiv_txt, dtormenta, causante, causan_txt, ncausant, gcc, causa_txt, clasedia, cdia_txt, estacion, hora, dulluvia, tempmax, h_relat, v_viento, d_viento, mod_com, mod_co_txt, p_ign, ind_pel, ind_pe_txt, tip_fuego, t_fueg_txt, medio, medio_txt, d_apie, tecnicos, agentes_f, cuadybrig, bomberos, volun_org, operciv, guarcivil, f_ejercit, autobomba, buldozzer, tractores, otros, avianfnum, avianfdes, avicarnum, avicardes, helextnum, helextbt, helextdes, heltranum, heltrabt, heltrades, aercoonum, retard, retard_txt, ataque, ataque_txt, tatacindi, tataci_txt, muertos, ...]
# ...
