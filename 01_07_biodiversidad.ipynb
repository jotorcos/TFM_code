# %%
import pandas as pd
import geopandas as gpd

# %%
bio = gpd.read_file("data/mfe_comunidadvalenciana/MFE_52.shp")

# %%
bio
# Out:
#        Poligon ORIGEN  PRO_F  ccaa_F ESTRATOIFN   Superficie  \
# 0        70546  MFE50      3      52         00    30.644799
# 1        70589  MFE50      3      52         00  1027.492338
# 2        70590  MFE50      3      52         00  2076.526976
# 3        70830  MFE50      3      52         00   123.731606
# 4        71126  MFE50      3      52         02     3.333223
# ...        ...    ...    ...     ...        ...          ...
# 52389   710734  MFE50     12      52         01    17.929427
# 52390   710735  MFE50     12      52         00     0.641739
# 52391   747643  MFE50     12      52         08    14.177645
# 52392  1334877  MFE50     12      52         02    39.115509
# 52393  1334897  MFE50     12      52         01    32.066559
#
#                    NUT2_NOM   NUT3_NOM  TIPESTR50  \
# 0      Comunitat Valenciana   Alicante         22
# 1      Comunitat Valenciana   Alicante         15
# 2      Comunitat Valenciana   Alicante         15
# ...

# %%
bio.to_file('data/biodiversidad.geojson', driver='GeoJSON')

# %%
biodiversidad = gpd.read_file("data/biodiversidad.geojson")

# %%
type(biodiversidad)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
biodiversidad.plot()
# Out:
# <Axes: >

# %%
biodiversidad
# Out:
#        Poligon ORIGEN  PRO_F  ccaa_F ESTRATOIFN   Superficie  \
# 0        70546  MFE50      3      52         00    30.644799
# 1        70589  MFE50      3      52         00  1027.492338
# 2        70590  MFE50      3      52         00  2076.526976
# 3        70830  MFE50      3      52         00   123.731606
# 4        71126  MFE50      3      52         02     3.333223
# ...        ...    ...    ...     ...        ...          ...
# 52389   710734  MFE50     12      52         01    17.929427
# 52390   710735  MFE50     12      52         00     0.641739
# 52391   747643  MFE50     12      52         08    14.177645
# 52392  1334877  MFE50     12      52         02    39.115509
# 52393  1334897  MFE50     12      52         01    32.066559
#
#                    NUT2_NOM   NUT3_NOM  TIPESTR50  \
# 0      Comunitat Valenciana   Alicante         22
# 1      Comunitat Valenciana   Alicante         15
# 2      Comunitat Valenciana   Alicante         15
# ...

# %%
biodiversidad.columns
# Out:
# Index(['Poligon', 'ORIGEN', 'PRO_F', 'ccaa_F', 'ESTRATOIFN', 'Superficie',
#        'NUT2_NOM', 'NUT3_NOM', 'TIPESTR50', 'TipoEstruc', 'FCCARB', 'FORARB',
#        'FormArbol', 'n_distribu', 'Distribuci', 'n_sp1', 'Especie1', 'O1',
#        'n_estado1', 'Estado1', 'n_sp2', 'Especie2', 'O2', 'n_estado2',
#        'Estado2', 'n_sp3', 'Especie3', 'O3', 'n_estado3', 'Estado3', 'FCCMAT',
#        'n_FORmat', 'FormArbust', 'HMMAT', 'FCCHER', 'n_FORHER', 'FormHerbac',
#        'n_ATRIBUTO', 'atributo', 'FCCTOT', 'n_MODCOM', 'ModeloComb',
#        'TIPOBOSQUE', 'n_CLAIFN', 'UsoIFN', 'n_CLAMFE', 'UsoMFE', 'n_REGBIO',
#        'RegBio', 'LULUCF', 'Shape_Area', 'geometry'],
#       dtype='object')

# %%
biodiversidad['n_CLAIFN'].unique()
# Out:
# array([300, 200, 500, 111, 141, 112, 161, 150, 121, 140, 114, 400, 171,
#        122, 142, 174, 172, 132, 124, 131, 163])

# %%
biodiversidad['UsoIFN'].unique()
# Out:
# array(['Artificial', 'Agrícola', 'Agua', 'Monte arbolado. Bosque',
#        'Monte desarbolado. Matorral',
#        'Monte arbolado. Bosque de plantaciones', 'Monte arbolado',
#        'Monte sin vegetación superior. Superficie con escasa o nula vegetación',
#        'Monte con arbolado ralo. Bosque', 'Monte desarbolado', 'Humedal',
#        'Monte desarbolado con arbolado disperso. Arbolado disperso',
#        'Monte con arbolado ralo. Bosque de plantaciones',
#        'Monte desarbolado. Herbazal o pastizal',
#        'Monte con arbolado disperso',
#        'Monte con arbolado disperso de plantación',
#        'Monte arbolado temporalmente sin cobertura. Incendios',
#        'Monte con arbolado ralo',
#        'Monte arbolado temporalmente sin cobertura. Talas'], dtype=object)

# %%
biodiversidad['UsoMFE'].unique()
# Out:
# array(['Artificial', 'Cultivos', 'Agua', 'Arbolado', 'Desarbolado',
#        'Arbolado ralo', 'Humedales. Desarbolado', 'Arbolado disperso'],
#       dtype=object)

# %%
biodiversidad['TIPOBOSQUE'].unique()
# Out:
# array(['-', 'Coníferas', 'Frondosas', 'Masas mixtas'], dtype=object)

# %%
biodiversidad['ModeloComb'].unique()
# Out:
# array([None], dtype=object)

# %%
biodiversidad.crs
# Out:
# <Projected CRS: EPSG:25830>
# Name: ETRS89 / UTM zone 30N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Europe between 6°W and 0°W: Faroe Islands offshore; Ireland - offshore; Jan Mayen - offshore; Norway including Svalbard - offshore; Spain - onshore and offshore.
# - bounds: (-6.0, 35.26, 0.0, 80.53)
# Coordinate Operation:
# - name: UTM zone 30N
# - method: Transverse Mercator
# Datum: European Terrestrial Reference System 1989
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
biodiversidad_projected = biodiversidad.to_crs('EPSG:4326')

# %%
biodiversidad_projected.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
biodiversidad_projected
# Out:
#        Poligon ORIGEN  PRO_F  ccaa_F ESTRATOIFN   Superficie  \
# 0        70546  MFE50      3      52         00    30.644799
# 1        70589  MFE50      3      52         00  1027.492338
# 2        70590  MFE50      3      52         00  2076.526976
# 3        70830  MFE50      3      52         00   123.731606
# 4        71126  MFE50      3      52         02     3.333223
# ...        ...    ...    ...     ...        ...          ...
# 52389   710734  MFE50     12      52         01    17.929427
# 52390   710735  MFE50     12      52         00     0.641739
# 52391   747643  MFE50     12      52         08    14.177645
# 52392  1334877  MFE50     12      52         02    39.115509
# 52393  1334897  MFE50     12      52         01    32.066559
#
#                    NUT2_NOM   NUT3_NOM  TIPESTR50  \
# 0      Comunitat Valenciana   Alicante         22
# 1      Comunitat Valenciana   Alicante         15
# 2      Comunitat Valenciana   Alicante         15
# ...

# %%
points_tridimensional_df = gpd.read_file("data/points_terrain_stats.geojson")

# %%
points_tridimensional_df.crs
# Out:
# <Geographic 2D CRS: EPSG:4258>
# Name: ETRS89
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: Europe - onshore and offshore: Albania; Andorra; Austria; Belgium; Bosnia and Herzegovina; Bulgaria; Croatia; Cyprus; Czechia; Denmark; Estonia; Faroe Islands; Finland; France; Germany; Gibraltar; Greece; Hungary; Ireland; Italy; Kosovo; Latvia; Liechtenstein; Lithuania; Luxembourg; Malta; Moldova; Monaco; Montenegro; Netherlands; North Macedonia; Norway including Svalbard and Jan Mayen; Poland; Portugal; Romania; San Marino; Serbia; Slovakia; Slovenia; Spain; Sweden; Switzerland; United Kingdom (UK) including Channel Islands and Isle of Man; Vatican City State.
# - bounds: (-16.1, 32.88, 40.18, 84.17)
# Datum: European Terrestrial Reference System 1989
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
points_tridimensional_df_projected = points_tridimensional_df.to_crs('EPSG:4326')

# %%
points_tridimensional_df_projected.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
points_tridimensional_df_projected
# Out:
#           altitud   pendiente  orientacion  is_fire date  \
# 0       644.62350   53.724090    30.371418    False  NaT
# 1         3.00000    0.351406   350.168950    False  NaT
# 2       155.06900   29.476328   135.866000    False  NaT
# 3       376.10925    5.116585    15.310265    False  NaT
# 4        10.27825    1.370338    12.806389    False  NaT
# ...           ...         ...          ...      ...  ...
# 102662  412.71725   47.693090   282.219500    False  NaT
# 102663   38.34275    3.802766    29.704033    False  NaT
# 102664  141.42924   23.073492    27.285748    False  NaT
# 102665   85.26525   13.172064   344.150270    False  NaT
# 102666  437.15350  122.548840   332.573550    False  NaT
#
#                                   geometry
# 0       POINT (750538.87013 4298747.17479)
# 1       POINT (752713.87013 4306437.17479)
# 2       POINT (754363.87013 4299307.17479)
# 3       POINT (747333.87013 4299187.17479)
# 4       POINT (753578.87013 4304332.17479)
# ...

# %%
points_within_biodiversidad = gpd.sjoin(points_tridimensional_df, biodiversidad, predicate='within')
points_within_biodiversidad
# Out:
# /var/folders/t1/7d5rd_ws0jn7w36r2y1h1m_40000gn/T/ipykernel_70279/1550921630.py:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: EPSG:4258
# Right CRS: EPSG:25830
#
#   points_within_biodiversidad = gpd.sjoin(points_tridimensional_df, biodiversidad, predicate='within')
#          altitud   pendiente  orientacion  is_fire       date  \
# 0      644.62350   53.724090    30.371418    False        NaT
# 7      462.58950   48.272960   178.964360     True 2015-05-14
# 16     388.61575   59.145134   272.722630     True 2015-05-14
# 21     186.00400   64.174590   110.825650    False        NaT
# 23     430.73900   65.798060    46.656640    False        NaT
# ...          ...         ...          ...      ...        ...
# 72021  133.49701   59.942820    29.433777    False        NaT
# ...

# %%
points_within_biodiversidad.columns
# Out:
# Index(['altitud', 'pendiente', 'orientacion', 'is_fire', 'date', 'geometry',
#        'index_right', 'Poligon', 'ORIGEN', 'PRO_F', 'ccaa_F', 'ESTRATOIFN',
#        'Superficie', 'NUT2_NOM', 'NUT3_NOM', 'TIPESTR50', 'TipoEstruc',
#        'FCCARB', 'FORARB', 'FormArbol', 'n_distribu', 'Distribuci', 'n_sp1',
#        'Especie1', 'O1', 'n_estado1', 'Estado1', 'n_sp2', 'Especie2', 'O2',
#        'n_estado2', 'Estado2', 'n_sp3', 'Especie3', 'O3', 'n_estado3',
#        'Estado3', 'FCCMAT', 'n_FORmat', 'FormArbust', 'HMMAT', 'FCCHER',
#        'n_FORHER', 'FormHerbac', 'n_ATRIBUTO', 'atributo', 'FCCTOT',
#        'n_MODCOM', 'ModeloComb', 'TIPOBOSQUE', 'n_CLAIFN', 'UsoIFN',
#        'n_CLAMFE', 'UsoMFE', 'n_REGBIO', 'RegBio', 'LULUCF', 'Shape_Area'],
#       dtype='object')

# %%
type(points_within_biodiversidad)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
len(points_within_biodiversidad)
# Out:
# 102667

# %%
len(points_tridimensional_df)
# Out:
# 102667

# %%
points_within_biodiversidad.to_file('data/points_tridimensional_biodiversidad.geojson', driver='GeoJSON')
