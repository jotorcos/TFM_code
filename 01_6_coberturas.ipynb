# %%
import pandas as pd
import geopandas as gpd

# %%
coberturas = gpd.read_file("data/coberturas/T_POLIGONOS.shp")

# %%
coberturas
# Out:
#                                   ID_POLYGON  \
# 0       e567da31-d8fd-4996-93e8-5a3efecced61
# 1       111b1d74-c8f6-407a-8e51-2a5c1feda6e4
# 2       05b8e4dd-9001-49a1-8f90-080cf95f3dd2
# 3       3ed56e71-6a47-4893-8a20-67e4801abe34
# 4       3528dbd9-b3f0-4379-9b12-1ff886d94c7c
# ...                                      ...
# 159862  b1464008-91d2-4b9a-8b6b-f3e8c6c347d3
# 159863  08c25083-c5ab-4faf-95c6-300afce67092
# 159864  800accc0-d041-4b1f-b504-aba3381137f4
# 159865  57f12233-afcb-4a88-8329-0a7c60023ce8
# 159866  9fc8d07f-1f98-4551-9ef8-ccf3bbafa718
#
#                                   SIOSE_CODE SIOSE_XML    SUPERF_HA  CODBLQ  \
# 0       NPO(30VAP_25SNE_20OCT_15EDFnv_10ZAU)      None   270.361644      10
# 1            R(70PSTpc_30IAS(80SNE_20EDFnv))      None     1.483062      10
# 2                           I(95PST_05EDFea)      None     1.098938      10
# 3                     I(60PST_20CNF_20SDNze)      None    17.411857      10
# ...

# %%
coberturas['OBS_N'].unique()
# Out:
# array([None, '2'], dtype=object)
